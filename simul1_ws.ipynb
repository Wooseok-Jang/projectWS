# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
np.random.seed(1)

# %% [markdown]
# ## User Class

# %%
class User:
    def __init__(self, user_id, age, sex, risk_taking, company_interest, industry_interest):
        """[User Class]

        Args:
            user_id ([int]): [user_id ex. 000124]
            age ([int]): [0: 20~29, 1:30~39, 2: 40~49, 3: 50~59]
            sex ([int]): [0: Male, 1: Female]
            risk_taking ([int]): [0: Low, 1: Mid, 2: High]
            company_interest ([int])
                : [0: Apple(AAPL), 1: Google(GOOG), 2: Amazon(AMZN), 3: Facebook(FB), 4: Microsoft(MSFT), 5: Visa(V),
                6: Tesla(TSLA), 7: JP Morgan Chase(JPM), 8: P&G(PG), 9: Nvidia(NVDA), 10: Pfizer(PFE)]
            industry_interest ([int])
                : [1: IT, 2: Healthcare, 3: Financials, 4: Energy, 5: Industrials]
        """
        self.user_id = user_id
        self.age = age
        self.sex = sex
        self.risk_taking = risk_taking
        self.company_interest = company_interest
        self.industry_interest = industry_interest
    
    def to_vector(self):
        self.user_vec = [self.user_id,
                         [self.age,
                         self.sex,
                         self.risk_taking,
                         self.company_interest,
                         self.industry_interest]]
        return self.user_vec

    def to_one_hot_vector(self):
        pass
        
    def __str__(self):
        return f"[User info] \n id: {self.user_id} \n age: {self.age} \n sex: {self.sex} \n risk_taking: {self.risk_taking} \n company_interest: {self.company_interest} \n industry_interest:{self.industry_interest} \n"

# %%
# User Example
user1 = User('%06d'%(np.random.random(1)[0]*100000), np.random.randint(4), 
            np.random.randint(2), np.random.randint(3), np.random.randint(10), np.random.randint(5))

# user1 = User('%06d'%(np.random.random(1)[0]*100000), 30, 'Male', 'High', 'Apple', 'ICT')
print(user1)
print(user1.to_vector())
# Out:
# [User info]
#  id: 054881
#  age: 1
#  sex: 0
#  risk_taking: 1
#  company_interest: 3
#  industry_interest:2
#
# ['054881', [1, 0, 1, 3, 2]]

# %% [markdown]
# ## Article Class

# %%
class Article:
    
    keyword_list = [['Apple',1], ['M&A',2], ['Startup',5], ['Samsung',9],['iPhone12',1.1],
                    ['Galaxy20',9.1], ['R&D',4.5], ['Coupang',20], ['Pfizer',100], ['COVID',103]]
    # 0: Apple, 1: M&A, 2: Startup, 3: Samsung, 4: iPhone12, ... 
    
    def __init__(self, article_id, keyword):
        self.article_id = article_id
        self.keyword = keyword
        
    def __str__(self):
        return f'[Article Keywords] \n id: {self.article_id} \n keywords: {self.keyword} \n'

# %%
# Article Example
article1 = Article("%06d"%(np.random.random(1)[0]*100000), 
                   [Article.keyword_list[np.random.randint(len(Article.keyword_list))], 
                    Article.keyword_list[np.random.randint(len(Article.keyword_list))], 
                    Article.keyword_list[np.random.randint(len(Article.keyword_list))]])
print(article1)
# Out:
# [Article Keywords]
#  id: 043758
#  keywords: [['R&D', 4.5], ['Pfizer', 100], ['Pfizer', 100]]

# %% [markdown]
# ## Generate User Datasets

# %%
USERS = []

for i in range(100):
    USERS.append(User('%06d'%(np.random.random(1)[0]*100000), np.random.randint(4), 
                 np.random.randint(2), np.random.randint(3), np.random.randint(10), np.random.randint(5)))

print(f'USERS shape: {np.shape(USERS)} \n')

for i, e in enumerate(USERS):
    # print(e)
    print(e.to_vector())
# Out:
# USERS shape: (100,)
#
# ['027265', [1, 0, 2, 8, 1]]
# ['092559', [1, 0, 1, 4, 3]]
# ['036824', [1, 0, 0, 2, 3]]
# ['079915', [3, 1, 2, 7, 0]]
# ['058201', [1, 1, 0, 4, 3]]
# ['018633', [2, 1, 0, 2, 0]]
# ['001878', [1, 1, 2, 8, 4]]
# ['038648', [0, 1, 2, 8, 1]]
# ['069763', [1, 1, 2, 7, 3]]
# ['021038', [3, 0, 2, 3, 4]]
# ['057019', [0, 1, 0, 6, 4]]
# ['065279', [0, 1, 0, 4, 4]]
# ['025329', [3, 0, 2, 7, 0]]
# ['013818', [1, 1, 0, 5, 0]]
# ['062284', [0, 0, 0, 3, 2]]
# ['050962', [0, 1, 1, 9, 0]]
# ['044171', [3, 0, 2, 9, 2]]
# ['088047', [2, 1, 2, 3, 4]]
# ['026538', [3, 0, 1, 1, 4]]
# ['092929', [3, 0, 2, 3, 0]]
# ['071632', [0, 0, 2, 3, 0]]
# ['016494', [1, 0, 0, 2, 3]]
# ['070373', [3, 1, 0, 8, 0]]
# ['057615', [0, 0, 2, 8, 4]]
# ['089155', [1, 0, 0, 4, 3]]
# ['069947', [0, 0, 1, 9, 3]]
# ['088110', [0, 1, 1, 9, 0]]
# ['072525', [2, 1, 1, 3, 1]]
# ['039486', [0, 1, 1, 6, 0]]
# ['038346', [1, 0, 0, 6, 3]]
# ['009237', [1, 1, 1, 6, 4]]
# ['096896', [0, 1, 2, 3, 2]]
# ['009725', [3, 0, 2, 5, 3]]
# ['010022', [0, 0, 2, 6, 3]]
# ['084114', [0, 1, 0, 2, 3]]
# ['061555', [3, 1, 2, 4, 3]]
# ['040718', [1, 1, 1, 7, 3]]
# ['042007', [2, 0, 1, 7, 1]]
# ['017162', [2, 0, 1, 5, 0]]
# ['017949', [0, 1, 2, 5, 0]]
# ['060825', [1, 1, 1, 0, 3]]
# ['062147', [0, 0, 0, 0, 1]]
# ['026726', [0, 1, 2, 1, 1]]
# ['031194', [1, 0, 1, 2, 4]]
# ['056957', [1, 0, 1, 7, 3]]
# ['005641', [1, 0, 2, 3, 1]]
# ['054249', [2, 1, 1, 9, 2]]
# ['045369', [1, 0, 1, 9, 2]]
# ['021689', [3, 0, 2, 4, 0]]
# ['075837', [3, 1, 0, 8, 3]]
# ['032468', [2, 1, 0, 3, 0]]
# ['027354', [1, 0, 1, 8, 4]]
# ['045612', [3, 0, 0, 9, 0]]
# ['073085', [2, 0, 0, 2, 4]]
# ['047175', [2, 1, 0, 5, 0]]
# ['021488', [3, 1, 0, 7, 4]]
# ['067484', [2, 0, 2, 1, 3]]
# ['039605', [1, 0, 1, 2, 3]]
# ['016495', [2, 1, 0, 2, 1]]
# ['090371', [1, 0, 2, 0, 2]]
# ['096193', [2, 1, 2, 9, 4]]
# ['006303', [2, 0, 0, 8, 0]]
# ['070349', [0, 1, 1, 8, 3]]
# ['097749', [3, 0, 1, 2, 4]]
# ['045516', [2, 1, 0, 4, 4]]
# ['048615', [3, 0, 2, 9, 4]]
# ['084894', [1, 1, 1, 1, 3]]
# ['014814', [3, 0, 2, 7, 1]]
# ['000404', [2, 0, 0, 4, 1]]
# ['029784', [0, 1, 2, 1, 4]]
# ['040612', [0, 0, 2, 8, 3]]
# ['035927', [3, 0, 2, 9, 4]]
# ['023223', [3, 1, 0, 2, 1]]
# ['001394', [1, 1, 0, 4, 2]]
# ['025062', [0, 1, 0, 4, 3]]
# ['075213', [3, 0, 1, 8, 4]]
# ['027032', [0, 0, 0, 8, 3]]
# ['026211', [1, 1, 1, 8, 4]]
# ['037992', [1, 1, 0, 3, 4]]
# ['069699', [3, 0, 1, 9, 3]]
# ['058759', [1, 0, 0, 0, 0]]
# ['092516', [1, 0, 2, 7, 0]]
# ['030681', [2, 0, 2, 1, 4]]
# ['003536', [2, 1, 1, 4, 1]]
# ['014382', [1, 1, 2, 4, 1]]
# ['014701', [0, 1, 2, 4, 1]]
# ['054380', [2, 1, 2, 3, 1]]
# ['072416', [2, 0, 2, 2, 2]]
# ['058019', [2, 0, 1, 8, 0]]
# ['000976', [1, 1, 2, 6, 1]]
# ['045722', [3, 0, 0, 1, 1]]
# ['090884', [0, 0, 1, 6, 4]]
# ['039843', [2, 0, 2, 2, 1]]
# ['084903', [1, 0, 2, 8, 3]]
# ['044387', [0, 0, 0, 8, 1]]
# ['053627', [0, 0, 0, 5, 3]]
# ['005596', [2, 0, 2, 3, 2]]
# ['001560', [2, 1, 1, 9, 4]]
# ['058015', [1, 1, 1, 3, 3]]
# ['061848', [2, 1, 1, 5, 0]]

# %%
print(USERS[10])
print(USERS[10].to_vector())
# Out:
# [User info]
#  id: 057019
#  age: 0
#  sex: 1
#  risk_taking: 0
#  company_interest: 6
#  industry_interest:4
#
# ['057019', [0, 1, 0, 6, 4]]

# %%
user1_to_vec = USERS[10].to_vector()[1]
print(user1_to_vec)
# enc = OneHotEncoder(handle_unknown='ignore')
# enc.fit(user1_to_vec)
# Out:
# [0, 1, 0, 6, 4]

# %% [markdown]
# ## Generate Article Datasets

# %%
ARTICLES = []

for i in range(100):
    ARTICLES.append(Article("%06d"%(np.random.random(1)[0]*100000), 
                   [Article.keyword_list[np.random.randint(len(Article.keyword_list))], 
                    Article.keyword_list[np.random.randint(len(Article.keyword_list))], 
                    Article.keyword_list[np.random.randint(len(Article.keyword_list))]]))

print(f'ARTICLES shape: {np.shape(ARTICLES)} \n')

for i, e in enumerate(ARTICLES):
    print(e)
    # print(e.to_vector())
# Out:
# ARTICLES shape: (100,)
#
# [Article Keywords]
#  id: 083151
#  keywords: [['Coupang', 20], ['Galaxy20', 9.1], ['M&A', 2]]
#
# [Article Keywords]
#  id: 036810
#  keywords: [['R&D', 4.5], ['Pfizer', 100], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 024606
#  keywords: [['Samsung', 9], ['Startup', 5], ['COVID', 103]]
#
# [Article Keywords]
#  id: 042783
#  keywords: [['Samsung', 9], ['Startup', 5], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 036054
#  keywords: [['M&A', 2], ['Galaxy20', 9.1], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 073868
#  keywords: [['Pfizer', 100], ['iPhone12', 1.1], ['M&A', 2]]
#
# [Article Keywords]
#  id: 025723
#  keywords: [['M&A', 2], ['Startup', 5], ['M&A', 2]]
#
# [Article Keywords]
#  id: 090494
#  keywords: [['Coupang', 20], ['Galaxy20', 9.1], ['Apple', 1]]
#
# [Article Keywords]
#  id: 022826
#  keywords: [['M&A', 2], ['M&A', 2], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 068976
#  keywords: [['Apple', 1], ['Startup', 5], ['Samsung', 9]]
#
# [Article Keywords]
#  id: 011381
#  keywords: [['COVID', 103], ['Startup', 5], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 037429
#  keywords: [['Apple', 1], ['R&D', 4.5], ['COVID', 103]]
#
# [Article Keywords]
#  id: 017185
#  keywords: [['Coupang', 20], ['Samsung', 9], ['Apple', 1]]
#
# [Article Keywords]
#  id: 088596
#  keywords: [['iPhone12', 1.1], ['Apple', 1], ['Startup', 5]]
#
# [Article Keywords]
#  id: 094258
#  keywords: [['Coupang', 20], ['M&A', 2], ['Samsung', 9]]
#
# [Article Keywords]
#  id: 075076
#  keywords: [['M&A', 2], ['Coupang', 20], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 099440
#  keywords: [['Startup', 5], ['Coupang', 20], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 067190
#  keywords: [['R&D', 4.5], ['COVID', 103], ['Startup', 5]]
#
# [Article Keywords]
#  id: 013128
#  keywords: [['COVID', 103], ['COVID', 103], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 089538
#  keywords: [['iPhone12', 1.1], ['COVID', 103], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 014847
#  keywords: [['Coupang', 20], ['Apple', 1], ['M&A', 2]]
#
# [Article Keywords]
#  id: 057991
#  keywords: [['COVID', 103], ['Startup', 5], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 045544
#  keywords: [['Pfizer', 100], ['Startup', 5], ['COVID', 103]]
#
# [Article Keywords]
#  id: 070860
#  keywords: [['Pfizer', 100], ['Startup', 5], ['Samsung', 9]]
#
# [Article Keywords]
#  id: 062563
#  keywords: [['R&D', 4.5], ['Apple', 1], ['Samsung', 9]]
#
# [Article Keywords]
#  id: 004869
#  keywords: [['Samsung', 9], ['COVID', 103], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 088923
#  keywords: [['Startup', 5], ['Startup', 5], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 074009
#  keywords: [['R&D', 4.5], ['Apple', 1], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 094470
#  keywords: [['Startup', 5], ['M&A', 2], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 067624
#  keywords: [['Galaxy20', 9.1], ['R&D', 4.5], ['M&A', 2]]
#
# [Article Keywords]
#  id: 028269
#  keywords: [['R&D', 4.5], ['R&D', 4.5], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 000788
#  keywords: [['Galaxy20', 9.1], ['Startup', 5], ['Startup', 5]]
#
# [Article Keywords]
#  id: 092211
#  keywords: [['COVID', 103], ['Samsung', 9], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 042550
#  keywords: [['Galaxy20', 9.1], ['M&A', 2], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 028977
#  keywords: [['COVID', 103], ['COVID', 103], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 064719
#  keywords: [['Apple', 1], ['Pfizer', 100], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 091479
#  keywords: [['Galaxy20', 9.1], ['Galaxy20', 9.1], ['M&A', 2]]
#
# [Article Keywords]
#  id: 068509
#  keywords: [['Apple', 1], ['Apple', 1], ['Apple', 1]]
#
# [Article Keywords]
#  id: 079084
#  keywords: [['Apple', 1], ['Coupang', 20], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 080666
#  keywords: [['iPhone12', 1.1], ['Samsung', 9], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 053911
#  keywords: [['M&A', 2], ['Samsung', 9], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 040442
#  keywords: [['Apple', 1], ['Apple', 1], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 037935
#  keywords: [['Samsung', 9], ['Samsung', 9], ['Apple', 1]]
#
# [Article Keywords]
#  id: 082989
#  keywords: [['iPhone12', 1.1], ['iPhone12', 1.1], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 011609
#  keywords: [['Pfizer', 100], ['Apple', 1], ['M&A', 2]]
#
# [Article Keywords]
#  id: 024653
#  keywords: [['COVID', 103], ['R&D', 4.5], ['M&A', 2]]
#
# [Article Keywords]
#  id: 044639
#  keywords: [['iPhone12', 1.1], ['Coupang', 20], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 066111
#  keywords: [['Coupang', 20], ['R&D', 4.5], ['Startup', 5]]
#
# [Article Keywords]
#  id: 069646
#  keywords: [['Apple', 1], ['Startup', 5], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 047466
#  keywords: [['Startup', 5], ['R&D', 4.5], ['M&A', 2]]
#
# [Article Keywords]
#  id: 067258
#  keywords: [['Apple', 1], ['Galaxy20', 9.1], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 000309
#  keywords: [['Galaxy20', 9.1], ['Samsung', 9], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 000518
#  keywords: [['Galaxy20', 9.1], ['iPhone12', 1.1], ['M&A', 2]]
#
# [Article Keywords]
#  id: 029314
#  keywords: [['Galaxy20', 9.1], ['Apple', 1], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 060724
#  keywords: [['R&D', 4.5], ['Samsung', 9], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 089065
#  keywords: [['Samsung', 9], ['R&D', 4.5], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 043178
#  keywords: [['COVID', 103], ['Pfizer', 100], ['M&A', 2]]
#
# [Article Keywords]
#  id: 065701
#  keywords: [['M&A', 2], ['Galaxy20', 9.1], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 044814
#  keywords: [['Coupang', 20], ['M&A', 2], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 097622
#  keywords: [['Coupang', 20], ['Galaxy20', 9.1], ['COVID', 103]]
#
# [Article Keywords]
#  id: 033549
#  keywords: [['Pfizer', 100], ['Coupang', 20], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 024190
#  keywords: [['Apple', 1], ['Apple', 1], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 017941
#  keywords: [['R&D', 4.5], ['M&A', 2], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 074539
#  keywords: [['Apple', 1], ['Coupang', 20], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 098342
#  keywords: [['Startup', 5], ['Coupang', 20], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 021153
#  keywords: [['Pfizer', 100], ['Galaxy20', 9.1], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 089875
#  keywords: [['M&A', 2], ['Galaxy20', 9.1], ['iPhone12', 1.1]]
#
# [Article Keywords]
#  id: 061918
#  keywords: [['R&D', 4.5], ['Samsung', 9], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 016902
#  keywords: [['iPhone12', 1.1], ['Startup', 5], ['COVID', 103]]
#
# [Article Keywords]
#  id: 027111
#  keywords: [['M&A', 2], ['Pfizer', 100], ['Startup', 5]]
#
# [Article Keywords]
#  id: 050839
#  keywords: [['iPhone12', 1.1], ['M&A', 2], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 027125
#  keywords: [['Galaxy20', 9.1], ['iPhone12', 1.1], ['COVID', 103]]
#
# [Article Keywords]
#  id: 012384
#  keywords: [['COVID', 103], ['iPhone12', 1.1], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 063918
#  keywords: [['iPhone12', 1.1], ['Startup', 5], ['Startup', 5]]
#
# [Article Keywords]
#  id: 066160
#  keywords: [['Samsung', 9], ['Apple', 1], ['M&A', 2]]
#
# [Article Keywords]
#  id: 067179
#  keywords: [['R&D', 4.5], ['COVID', 103], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 040503
#  keywords: [['Samsung', 9], ['Apple', 1], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 071392
#  keywords: [['Startup', 5], ['Galaxy20', 9.1], ['COVID', 103]]
#
# [Article Keywords]
#  id: 070321
#  keywords: [['Samsung', 9], ['iPhone12', 1.1], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 010329
#  keywords: [['Samsung', 9], ['R&D', 4.5], ['COVID', 103]]
#
# [Article Keywords]
#  id: 000120
#  keywords: [['Coupang', 20], ['M&A', 2], ['Samsung', 9]]
#
# [Article Keywords]
#  id: 079631
#  keywords: [['Coupang', 20], ['Pfizer', 100], ['Pfizer', 100]]
#
# [Article Keywords]
#  id: 051814
#  keywords: [['Samsung', 9], ['R&D', 4.5], ['COVID', 103]]
#
# [Article Keywords]
#  id: 063341
#  keywords: [['Startup', 5], ['COVID', 103], ['Samsung', 9]]
#
# [Article Keywords]
#  id: 000868
#  keywords: [['COVID', 103], ['Apple', 1], ['Coupang', 20]]
#
# [Article Keywords]
#  id: 016212
#  keywords: [['M&A', 2], ['Startup', 5], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 088495
#  keywords: [['Galaxy20', 9.1], ['Pfizer', 100], ['COVID', 103]]
#
# [Article Keywords]
#  id: 019959
#  keywords: [['Galaxy20', 9.1], ['Samsung', 9], ['M&A', 2]]
#
# [Article Keywords]
#  id: 007041
#  keywords: [['Samsung', 9], ['Pfizer', 100], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 016039
#  keywords: [['Galaxy20', 9.1], ['M&A', 2], ['COVID', 103]]
#
# [Article Keywords]
#  id: 069078
#  keywords: [['Startup', 5], ['M&A', 2], ['Apple', 1]]
#
# [Article Keywords]
#  id: 050106
#  keywords: [['M&A', 2], ['M&A', 2], ['R&D', 4.5]]
#
# [Article Keywords]
#  id: 026090
#  keywords: [['Samsung', 9], ['Startup', 5], ['Apple', 1]]
#
# [Article Keywords]
#  id: 009749
#  keywords: [['R&D', 4.5], ['Apple', 1], ['Galaxy20', 9.1]]
#
# [Article Keywords]
#  id: 023307
#  keywords: [['Samsung', 9], ['Samsung', 9], ['COVID', 103]]
#
# [Article Keywords]
#  id: 060898
#  keywords: [['iPhone12', 1.1], ['COVID', 103], ['Apple', 1]]
#
# [Article Keywords]
#  id: 068636
#  keywords: [['Samsung', 9], ['Apple', 1], ['Apple', 1]]
#
# [Article Keywords]
#  id: 032837
#  keywords: [['Apple', 1], ['Startup', 5], ['Startup', 5]]
#
# [Article Keywords]
#  id: 093081
#  keywords: [['Coupang', 20], ['Pfizer', 100], ['COVID', 103]]
#
# [Article Keywords]
#  id: 042594
#  keywords: [['Startup', 5], ['iPhone12', 1.1], ['Coupang', 20]]
